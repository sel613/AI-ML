# %%
data={"1": {"prod_name": "Five Star", "category": "chocalate", "prize": 25, "quantity": 10, "discount": 10},
"2": {"prod_name": "kit-kat", "category": "chocalate", "prize": 20, "quantity": 30, "discount": 15}, 
"3": {"prod_name": "SunFeast", "category": "Biscuit", "prize": 10, "quantity": 1000, "discount": 0}, 
"4": {"prod_name": "Tiger", "category": "Biscuit", "prize": 5, "quantity": 1076, "discount": 0}, 
"5": {"prod_name": "GoodDay", "category": "Biscuit", "prize": 10, "quantity": 10443, "discount": 0}, 
"6": {"prod_name": "MilkBikies", "category": "Biscuit", "prize": 10, "quantity": 1087, "discount": 5},
"7": {"prod_name": "50-50", "category": "Biscuit", "prize": 5, "quantity": 1098, "discount": 0},
"8": {"prod_name": "Parle-G", "category": "Biscuit", "prize": 5, "quantity": 1000, "discount": 0}, 
"9": {"prod_name": "Oreo", "category": "Biscuit", "prize": 25, "quantity": 2000, "discount": 0}, 
"10": {"prod_name": "Marie-Golg", "category": "Biscuit", "prize": 20, "quantity": 460, "discount": 0},
"11": {"prod_name": "Mazha", "category": "soft drink", "prize": 25, "quantity": 890, "discount": 0},
"12": {"prod_name": "7-Up", "category": "soft drink", "prize": 25, "quantity": 2350, "discount": 0}, 
"13": {"prod_name": "Sprite", "category": "soft drink", "prize": 25, "quantity": 1200, "discount": 15}, 
"14": {"prod_name": "Vanila", "category": "icecream", "prize": 20, "quantity": 2350, "discount": 30}, 
"15": {"prod_name": "Mango", "category": "icecream", "prize": 20, "quantity": 7890, "discount": 4}, 
"16": {"prod_name": "Chocolate", "category": "icecream", "prize": 20, "quantity": 1230, "discount": 5},
"17": {"prod_name": "Bingo", "category": "snack", "prize": 10, "quantity": 4560, "discount": 6},
"18": {"prod_name": "Kur-kure", "category": "snack", "prize": 10, "quantity": 1000, "discount": 6}, 
"19": {"prod_name": "Lays", "category": "snack", "prize": 10, "quantity": 1010, "discount": 1},
"20": {"prod_name": "MAGGIE", "category": "snack", "prize": 10, "quantity": 1500, "discount": 18},
"21": {"prod_name": "potAto-chip", "category": "snack", "prize": 10, "quantity": 500, "discount": 21},
"22": {"prod_name": "tomato-chip", "category": "snack", "prize": 10, "quantity": 600, "discount": 13},
"23": {"prod_name": "fruiti", "category": "soft drink", "prize": 25, "quantity": 700, "discount": 0},
"24": {"prod_name": "Lemo", "category": "soft drink", "prize": 25, "quantity": 8000, "discount": 10}, 
"25": {"prod_name": "Cadbury", "category": "chocalate", "prize": 25, "quantity": 5689, "discount": 10},
"26": {"prod_name": "perk", "category": "chocalate", "prize": 25, "quantity": 1230, "discount": 10}, 
"27": {"prod_name": "munch", "category": "chocalate", "prize": 25, "quantity": 1500, "discount": 10}, 
"28": {"prod_name": "Snickers", "category": "chocalate", "prize": 25, "quantity": 6500, "discount": 10}, 
"29": {"prod_name": "Twix", "category": "chocalate", "prize": 25, "quantity": 10, "discount": 10},
"30": {"prod_name": "Dagoba", "category": "chocalate", "prize": 25, "quantity": 10, "discount": 10}}

# %%
import json

# %%
js_data=json.dumps(data)

# %%
js_data
# Out:
# '{"1": {"prod_name": "Five Star", "category": "chocalate", "prize": 25, "quantity": 10, "discount": 10}, "2": {"prod_name": "kit-kat", "category": "chocalate", "prize": 20, "quantity": 30, "discount": 15}, "3": {"prod_name": "SunFeast", "category": "Biscuit", "prize": 10, "quantity": 1000, "discount": 0}, "4": {"prod_name": "Tiger", "category": "Biscuit", "prize": 5, "quantity": 1076, "discount": 0}, "5": {"prod_name": "GoodDay", "category": "Biscuit", "prize": 10, "quantity": 10443, "discount": 0}, "6": {"prod_name": "MilkBikies", "category": "Biscuit", "prize": 10, "quantity": 1087, "discount": 5}, "7": {"prod_name": "50-50", "category": "Biscuit", "prize": 5, "quantity": 1098, "discount": 0}, "8": {"prod_name": "Parle-G", "category": "Biscuit", "prize": 5, "quantity": 1000, "discount": 0}, "9": {"prod_name": "Oreo", "category": "Biscuit", "prize": 25, "quantity": 2000, "discount": 0}, "10": {"prod_name": "Marie-Golg", "category": "Biscuit", "prize": 20, "quantity": 460, "discount"
# ...

# %%
file_write=open("Records.json",'w')

# %%
file_write.write(js_data)
file_write.close()

# %%
file_read=open('Records.json','r')
js_data=file_read.read()
file_read.close()

# %%
js_data=json.loads(js_data)

# %%
js_data
# Out:
# {'1': {'prod_name': 'Five Star',
#   'category': 'chocalate',
#   'prize': 25,
#   'quantity': 10,
#   'discount': 10},
#  '2': {'prod_name': 'kit-kat',
#   'category': 'chocalate',
#   'prize': 20,
#   'quantity': 30,
#   'discount': 15},
#  '3': {'prod_name': 'SunFeast',
#   'category': 'Biscuit',
#   'prize': 10,
#   'quantity': 1000,
#   'discount': 0},
#  '4': {'prod_name': 'Tiger',
#   'category': 'Biscuit',
#   'prize': 5,
#   'quantity': 1076,
#   'discount': 0},
#  '5': {'prod_name': 'GoodDay',
#   'category': 'Biscuit',
#   'prize': 10,
#   'quantity': 10443,
#   'discount': 0},
#  '6': {'prod_name': 'MilkBikies',
#   'category': 'Biscuit',
#   'prize': 10,
#   'quantity': 1087,
#   'discount': 5},
#  '7': {'prod_name': '50-50',
#   'category': 'Biscuit',
#   'prize': 5,
#   'quantity': 1098,
#   'discount': 0},
#  '8': {'prod_name': 'Parle-G',
#   'category': 'Biscuit',
#   'prize': 5,
#   'quantity': 1000,
#   'discount': 0},
#  '9': {'prod_name': 'Oreo',
# ...

# %% [markdown]
# # Adding an item to Inventory

# %%
insert=input("Need To Add Item To Inventory(Y/N)")
if(insert=='Y'):
    id=int(input("Enter product id : "))
    name=input("Enter product name : ")
    category=input("Enter product category : ")
    prize=int(input("Enter product prize : "))
    qty=int(input("Enter product quantity : "))
    dis=int(input("Enter product discount(%) : "))
    js_data[id]={}
    js_data[id]["prod_name"]=name
    js_data[id]["category"]=category
    js_data[id]["prize"]=prize
    js_data[id]["quantity"]=qty
    js_data[id]["discount"]=dis
    print("*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*")
    print("")
    print("")
    print("                            Item Added Successfully to the Record")
else:
    print("*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*")
    print("")
    print("")
    print("                            Redo / Retry To add")
# Out:
# Need To Add Item To Inventory(Y/N)Y
# Enter product id : 31
# Enter product name : Snikkers
# Enter product category : Chocalate
# Enter product prize : 15
# Enter product quantity : 25
# Enter product discount(%) : 2
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*
#
#
#                             Item Added Successfully to the Record

# %%
js_data
# Out:
# {'1': {'prod_name': 'Five Star',
#   'category': 'chocalate',
#   'prize': 25,
#   'quantity': 10,
#   'discount': 10},
#  '2': {'prod_name': 'kit-kat',
#   'category': 'chocalate',
#   'prize': 20,
#   'quantity': 30,
#   'discount': 15},
#  '3': {'prod_name': 'SunFeast',
#   'category': 'Biscuit',
#   'prize': 10,
#   'quantity': 1000,
#   'discount': 0},
#  '4': {'prod_name': 'Tiger',
#   'category': 'Biscuit',
#   'prize': 5,
#   'quantity': 1076,
#   'discount': 0},
#  '5': {'prod_name': 'GoodDay',
#   'category': 'Biscuit',
#   'prize': 10,
#   'quantity': 10443,
#   'discount': 0},
#  '6': {'prod_name': 'MilkBikies',
#   'category': 'Biscuit',
#   'prize': 10,
#   'quantity': 1087,
#   'discount': 5},
#  '7': {'prod_name': '50-50',
#   'category': 'Biscuit',
#   'prize': 5,
#   'quantity': 1098,
#   'discount': 0},
#  '8': {'prod_name': 'Parle-G',
#   'category': 'Biscuit',
#   'prize': 5,
#   'quantity': 1000,
#   'discount': 0},
#  '9': {'prod_name': 'Oreo',
# ...

# %% [markdown]
# # Purchase Items in Inventory

# %%
import time
id=input("Enter Product Id : ")
qty=int(input("Enter Quantity of Item :"))
cust_name=input("Enter customer name :")
disc_amount=(js_data[id]["discount"]/100)*(js_data[id]["prize"])
print("Purchased Item :",js_data[id]["prod_name"])
print("prize per Item :",js_data[id]["prize"])
print("Amount To Pay:",js_data[id]["prize"]*qty)
js_data[id]["quantity"]=js_data[id]["quantity"]-qty     
print("**********************************************************************************************************")
print("                            AI/ML INVENTORY MANAGEMENT SYSTEM")
print("**********************************************************************************************************")
print("")
print("Name of Customer              :",cust_name)
print("Time & Date of shopping       :",time.ctime())
print("")
print("Product Purchased             :",js_data[id]["prod_name"])
print("                                                                                                          ")
print("Total Amount Without Discount :",js_data[id]["prize"]*qty)
print("                                                                                                          ")
print("Discount Amount in(%)              :",js_data[id]["discount"])
print("Amount Need to Pay            :",js_data[id]["prize"]*qty-disc_amount)
print("")
print("====================================  Thanks For Shopping With Us  ===============================================")
print("")
print("**********************************************************************************************************")
print("**********************************************************************************************************")
# Out:
# Enter Product Id : 3
# Enter Quantity of Item :2
# Enter customer name :selva
# Purchased Item : SunFeast
# prize per Item : 10
# Amount To Pay: 20
# **********************************************************************************************************
#                             AI/ML INVENTORY MANAGEMENT SYSTEM
# **********************************************************************************************************
#
# Name of Customer              : selva
# Time & Date of shopping       : Mon Sep  6 21:02:57 2021
#
# Product Purchased             : SunFeast
#
# Total Amount Without Discount : 20
#
# Discount Amount in(%)              : 0
# Amount Need to Pay            : 20.0
#
# ====================================  Thanks For Shopping With Us  ===============================================
#
# **********************************************************************************************************
# ...
